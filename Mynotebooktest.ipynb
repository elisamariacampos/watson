# %%
print("This is my first test, please be kind")
# Out:
# This is my first test, please be kind

# %% [markdown]
# <h1>"My Jupyter Notebook on IBM Watson Studio"</h1>

# %% [markdown]
# <b> My name is Elisa</b>
# I am a curious journalist and master student of sociology

# %% [markdown]
# <i> I am interested in Data Science because I had the crazy feeling I need to use it to help with more inclusive social policies in the Global South. Yes, I am Brazilian!</i>

# %% [markdown]
# <h3>Now I will execute a code to show you the most beautiful math that exists in the world. It demonstrates what we can do together, look:</h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# You are welcome to visit my webpage (http://www.peaceid.org).
# This is what you will find there:
# 1.About me
# 2.About the project
# 3.About Technology for development
# 4.Many English mistakes
# That's all for today!
# **********
# <h4> Thanks for reading </h4>
